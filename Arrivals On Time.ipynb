# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import csv

# %%
#csv_path = "Resources/Airline-On-Time1.csv
On_Time_df= pd.read_csv("Airline-On-Time.csv", skiprows=2)
On_Time_df
# Out:
#     Year Operations Late Arrivals Late Departures Cancelled Diverted  \
# 0   1995    464,933       106,076          86,193    14,261    1,348
# 1   1996    447,224       135,407         111,316    29,595    1,948
# 2   1997    459,123       125,428         100,351    18,142    1,484
# 3   1998    452,001        97,609          76,993    13,880    1,274
# 4   1999    453,814       118,153         100,762    26,543    2,048
# 5   2000    470,477        97,699          77,755    24,515    1,303
# 6   2001    529,940       109,367          92,872    19,891      975
# 7   2002    436,336        75,006          59,370     7,301      498
# 8   2003    552,109        82,900          66,453     8,341      847
# 9   2004    583,987       128,236         101,072    17,611    1,015
# 10  2005    594,924       143,316         122,637    25,084    1,809
# 11  2006    581,287       112,299         100,690     9,787    1,370
# 12  2007    621,559       150,144         128,259    15,777    1,200
# ...

# %%
year_pct_df = On_Time_df[ ['Year', 'Percent On-Time Arrivals'] ]

# %%
#year_pct_df.head()
year_pct_df
# Out:
#     Year  Percent On-Time Arrivals
# 0   1995                     73.83
# 1   1996                     62.67
# 2   1997                     68.41
# 3   1998                     75.05
# 4   1999                     67.66
# 5   2000                     73.75
# 6   2001                     75.42
# 7   2002                     81.02
# 8   2003                     83.32
# 9   2004                     74.85
# 10  2005                     71.39
# 11  2006                     78.76
# 12  2007                     73.11
# 13  2008                     72.36
# 14  2009                     77.02
# 15  2010                     78.69
# 16  2011                     76.30
# 17  2012                     83.75
# 18  2013                     80.98
# 19  2014                     67.72
# 20  2015                     76.83
# 21  2016                     81.29
# 22  2017                     75.99
# 23  2018                     79.62

# %%
#year_pct_df.plot()

# %%
# 
import matplotlib
import matplotlib.ticker as ticker
fig, ax = plt.subplots(1,1)
ax.xaxis.set_major_locator(matplotlib.ticker.IndexLocator(1, 1))
ax.xaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator())

ax.plot(year_pct_df['Year'], year_pct_df['Percent On-Time Arrivals'], color="orange", label="Years")
plt.legend(loc="best")
plt.title("Arrivals On Time Through the years")
plt.xlabel("years")
plt.ylabel("Percent Arrivals On Time")
plt.xlim(2007, 2019)
locs, labels = plt.xticks()

plt.setp(labels, rotation=90)
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="606.3157970819448">
