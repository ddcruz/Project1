# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_file = "AUS_passengers.csv"

# %%
csv_reader = pd.read_csv(csv_file)
df = pd.DataFrame(csv_reader)
df.head()
# Out:
#                     Month  Domestic Enplaned Passengers: Revenue  \
# 0  10/01/2018 12:00:00 AM                               674367.0
# 1  09/01/2018 12:00:00 AM                               584974.0
# 2  08/01/2018 12:00:00 AM                               644973.0
# 3  07/01/2018 12:00:00 AM                               687726.0
# 4  06/01/2018 12:00:00 AM                               699111.0
#
#    Domestic Deplaned Passengers: Revenue  \
# 0                               680722.0
# 1                               592853.0
# 2                               670876.0
# 3                               688887.0
# 4                               667742.0
#
#    International Enplaned Passengers: Revenue  \
# 0                                     13678.0
# 1                                     14350.0
# 2                                     17250.0
# 3                                     25814.0
# 4                                     26530.0
#
# ...

# %%
new_df = df[['Month', 'Total Passengers']]
new_df.head()
# Out:
#                     Month  Total Passengers
# 0  10/01/2018 12:00:00 AM         1434756.0
# 1  09/01/2018 12:00:00 AM         1249777.0
# 2  08/01/2018 12:00:00 AM         1413983.0
# 3  07/01/2018 12:00:00 AM         1511634.0
# 4  06/01/2018 12:00:00 AM         1489191.0

# %%
new_df['Month'].astype(str)
# Out:
# 0     10/01/2018 12:00:00 AM
# 1     09/01/2018 12:00:00 AM
# 2     08/01/2018 12:00:00 AM
# 3     07/01/2018 12:00:00 AM
# 4     06/01/2018 12:00:00 AM
# 5     05/01/2018 12:00:00 AM
# 6     04/01/2018 12:00:00 AM
# 7     03/01/2018 12:00:00 AM
# 8     02/01/2018 12:00:00 AM
# 9     01/01/2018 12:00:00 AM
# 10    12/01/2017 12:00:00 AM
# 11    11/01/2017 12:00:00 AM
# 12    10/01/2017 12:00:00 AM
# 13    09/01/2017 12:00:00 AM
# 14    08/01/2017 12:00:00 AM
# 15    07/01/2017 12:00:00 AM
# 16    06/01/2017 12:00:00 AM
# 17    05/01/2017 12:00:00 AM
# 18    04/01/2017 12:00:00 AM
# 19    03/01/2017 12:00:00 AM
# 20    02/01/2017 12:00:00 AM
# 21    01/01/2017 12:00:00 AM
# 22    12/01/2016 12:00:00 AM
# 23    11/01/2016 12:00:00 AM
# 24    10/01/2016 12:00:00 AM
# 25    09/01/2016 12:00:00 AM
# 26    08/01/2016 12:00:00 AM
# 27    07/01/2016 12:00:00 AM
# 28    06/01/2016 12:00:00 AM
# 29    05/01/2016 12:00:00 AM
#                ...
# 35    11/01/2015 12:00:00 AM
# ...

# %%
new_df['Year'] = ""
new_df['Months'] = ""
new_df.head()
# Out:
# /Users/atchoate/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/atchoate/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     Month  Total Passengers Year Months
# 0  10/01/2018 12:00:00 AM         1434756.0
# 1  09/01/2018 12:00:00 AM         1249777.0
# 2  08/01/2018 12:00:00 AM         1413983.0
# ...

# %%
bydate = new_df['Month'].str.split("/", expand=True)

# %%
new_df['Year'] = bydate[2]
new_df['Months'] = bydate[0]
# Out:
# /Users/atchoate/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/atchoate/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_df.head()
# Out:
#                     Month  Total Passengers              Year Months
# 0  10/01/2018 12:00:00 AM         1434756.0  2018 12:00:00 AM     10
# 1  09/01/2018 12:00:00 AM         1249777.0  2018 12:00:00 AM     09
# 2  08/01/2018 12:00:00 AM         1413983.0  2018 12:00:00 AM     08
# 3  07/01/2018 12:00:00 AM         1511634.0  2018 12:00:00 AM     07
# 4  06/01/2018 12:00:00 AM         1489191.0  2018 12:00:00 AM     06

# %%
byyear = new_df['Year'].str.split(" ", expand=True)

new_df['Years'] = byyear[0]
new_df.head()
# Out:
# /Users/atchoate/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                     Month  Total Passengers              Year Months Years
# 0  10/01/2018 12:00:00 AM         1434756.0  2018 12:00:00 AM     10  2018
# 1  09/01/2018 12:00:00 AM         1249777.0  2018 12:00:00 AM     09  2018
# 2  08/01/2018 12:00:00 AM         1413983.0  2018 12:00:00 AM     08  2018
# 3  07/01/2018 12:00:00 AM         1511634.0  2018 12:00:00 AM     07  2018
# 4  06/01/2018 12:00:00 AM         1489191.0  2018 12:00:00 AM     06  2018

# %%
final_df = new_df[['Months', 'Years', 'Total Passengers']]
final_df.head()
# Out:
#   Months Years  Total Passengers
# 0     10  2018         1434756.0
# 1     09  2018         1249777.0
# 2     08  2018         1413983.0
# 3     07  2018         1511634.0
# 4     06  2018         1489191.0

# %%
df2 = final_df.sort_values(by=['Years', 'Months'])
df2.head()
# Out:
#     index Months Years  Total Passengers
# 64     64     06  2013          911675.0
# 63     63     07  2013          922615.0
# 62     62     08  2013          877727.0
# 61     61     09  2013          785983.0
# 60     60     10  2013          878016.0

# %%
reset_df = df2.reset_index(drop=True)
reset_df.head()
# Out:
#    index Months Years  Total Passengers
# 0     64     06  2013          911675.0
# 1     63     07  2013          922615.0
# 2     62     08  2013          877727.0
# 3     61     09  2013          785983.0
# 4     60     10  2013          878016.0

# %%
reset_df.plot(x="Months", y="Total Passengers", kind="line")
plt.xlabel("By month, from June 2013 to October 2018")
plt.ylabel("No. of Passengers")
plt.title("Passenger Volume Growth at ABIA")
plt.savefig("monthly_passengers")

# %%
plt.savefig("passengers_by_month")
